# %% [markdown]
# - Clustering para Reino Unido

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

df_uk = pd.read_csv("../../data/dataset_uk_for_clustering.csv")

features_to_use = df_uk[['TotalSales', 'InvoiceNo', 'MediaTicket'] ]

dbscan = DBSCAN(eps=550, min_samples=5)

df_uk["Cluster"] = dbscan.fit_predict(features_to_use)

plt.figure(figsize=(10, 4))
sns.scatterplot(
  x='InvoiceNo', 
  y='TotalSales', 
  hue='Cluster',
  size='MediaTicket',
  sizes=(20, 200),
  alpha=0.6,
  palette='tab10',
  data=df_uk
)
plt.xlabel("Number of Invoices")
plt.ylabel("Total Sales")
plt.title("UK Customer Clusters DBSCAN")
plt.legend(loc='lower right')
plt.grid()
plt.show()

# %% [markdown]
# - Clustering para el resto

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN

df_rest = pd.read_csv("../../data/dataset_rest_for_clustering.csv")

features_to_use = df_rest[['TotalSales', 'InvoiceNo', 'MediaTicket']]

dbscan = DBSCAN(eps=150, min_samples=5)

df_rest["Cluster"] = dbscan.fit_predict(features_to_use)

plt.figure(figsize=(10, 4))
sns.scatterplot(
  x='InvoiceNo', 
  y='TotalSales', 
  hue='Cluster',
  size='MediaTicket',
  sizes=(20, 200),
  alpha=0.6,
  palette='tab10',
  data=df_rest
)
plt.xlabel("Number of Invoices")
plt.ylabel("Total Sales")
plt.title("Customer Clusters DBSCAN")
plt.legend(loc='lower right')
plt.grid()
plt.show()
